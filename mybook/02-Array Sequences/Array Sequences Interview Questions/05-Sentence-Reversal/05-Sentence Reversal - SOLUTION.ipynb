# %% [markdown]
# # 문장 반전
#
# ## 문제
#
# 일련의 단어가 주어지면 모든 단어를 뒤집어 보세요. 예를 들면:
#
# 주어진:
#
#     '이게 최고야'
#
# 반환:
#
#     '최고는 이것이다'
#
# 이 연습의 일환으로 모든 선행 및 후행 공백을 제거해야 합니다. 따라서 다음과 같은 입력이 이루어집니다.
#
#     '여기 공간'과 '여기 공간'
#
# 둘 다 다음과 같이 됩니다:
#
#     '여기 공간'
#
# ## 솔루션
#
# 우리는 Python의 능력을 활용하고split()**을 사용하고reversed**를 슬라이싱하거나 사용하여 문제를 해결할 수 있습니다.

# %%
def rev_word1(s):
    return " ".join(reversed(s.split()))


# Or


def rev_word2(s):
    return " ".join(s.split()[::-1])

# %%
rev_word1("Hi John,   are you ready to go?")
# Out:
# 'go? to ready you are John, Hi'

# %%
rev_word2("Hi John,   are you ready to go?")
# Out:
# 'go? to ready you are John, Hi'

# %% [markdown]
# 이는 유효한 솔루션이지만 인터뷰 환경에서는 사용되는 기본 알고리즘을 해결해야 합니다. 이 경우 우리가 원하는 것은 텍스트를 반복하고 문자열에서 단어를 추출하는 것입니다. 그런 다음 단어를 "스택"으로 푸시하고 결국에는 모두 뒤집을 수 있습니다. 이것이 실제로 어떻게 보이는지 봅시다:

# %%
def rev_word3(s):
    """
    Manually doing the splits on the spaces.
    """

    words = []
    length = len(s)
    spaces = [" "]

    # Index Tracker
    i = 0

    # While index is less than length of string
    while i < length:
        # If element isn't a space
        if s[i] not in spaces:
            # The word starts at this index
            word_start = i

            while i < length and s[i] not in spaces:
                # Get index where word ends
                i += 1
            # Append that word to the list
            words.append(s[word_start:i])
        # Add to index
        i += 1

    # Join the reversed words
    return " ".join(reversed(words))

# %%
rev_word3("   Hello John    how are you   ")
# Out:
# 'you are how John Hello'

# %%
rev_word3("    space before")
# Out:
# 'before space'

# %% [markdown]
# 원하는 경우 이 솔루션을 추가로 개발하여 모든 것이 수동으로 이루어지도록 할 수 있으며 자신만의 반전 기능을 만들 수 있습니다.

# %% [markdown]
# # 솔루션 테스트

# %%
"""
RUN THIS CELL TO TEST YOUR SOLUTION
"""

from nose.tools import assert_equal


class ReversalTest(object):
    def test(self, sol):
        assert_equal(sol("    space before"), "before space")
        assert_equal(sol("space after     "), "after space")
        assert_equal(sol("   Hello John    how are you   "), "you are how John Hello")
        assert_equal(sol("1"), "1")
        print("ALL TEST CASES PASSED")


# Run and test
t = ReversalTest()
t.test(rev_word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2dee392751be> in <module>
#      16 # Run and test
#      17 t = ReversalTest()
# ---> 18 t.test(rev_word)
#
# NameError: name 'rev_word' is not defined

# %% [markdown]
# ## 잘했어요!
