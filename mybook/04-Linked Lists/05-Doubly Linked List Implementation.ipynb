# %% [markdown]
# # 이중 연결 리스트 구현
#
# 이번 강의에서는 이중 연결 리스트를 구현해보겠습니다.

# %%
class DoublyLinkedListNode(object):
    def __init__(self, value):

        self.value = value
        self.next_node = None
        self.prev_node = None

# %% [markdown]
# 이제 다음 *및* 이전 값을 참조할 수 있는 노드가 있으므로 연결 목록 구축을 시작하겠습니다!

# %%
a = DoublyLinkedListNode(1)
b = DoublyLinkedListNode(2)
c = DoublyLinkedListNode(3)

# %%
# Setting b after a
b.prev_node = a
a.next_node = b

# %%
# Setting c after a
b.next_node = c
c.prev_node = b

# %% [markdown]
# 이중 연결 목록을 사용하면 연결 목록을 통해및뒤로 이동할 수 있습니다.

# %% [markdown]
# # 잘했어요!
