# %% [markdown]
# # 단일 연결 목록 구현
#
# 이 인터뷰 문제의 경우 노드 클래스를 만들고 이를 사용하여 단일 연결 목록을 만드는 방법을 보여줍니다.

# %%
class Node(object):
    pass

# %%
# Create a Singly Linked List here

# %% [markdown]
# # 솔루션 테스트
#
# 이 솔루션에 대한 테스트는 없습니다(답 구조를 제공하기 때문입니다).
#
# 이 인터뷰 문제에 대한 답변과 이중 연결 목록 구현에 대한 답변은 연결 목록 솔루션 노트북 구현을 확인하세요.
