# %% [markdown]
# # 병합 정렬 구현
#
# 병합 정렬은 목록을 계속해서 절반으로 나누는 재귀 알고리즘입니다. 목록이 비어 있거나 항목이 하나인 경우 정의(기본 사례)에 따라 정렬됩니다. 목록에 항목이 두 개 이상 있으면 목록을 분할하고 두 부분 모두에서 병합 정렬을 재귀적으로 호출합니다. 두 부분이 정렬되면 병합이라고 하는 기본 작업이 수행됩니다. 병합은 두 개의 작은 정렬된 목록을 가져와 하나의 정렬된 새 목록으로 결합하는 프로세스입니다.

# %% [markdown]
# # 검토를 위한 리소스
#
# 병합 정렬에 대한 검토는 아래 리소스를 확인하세요!
#
# * [위키피디아](https://en.wikipedia.org/wiki/Merge_sort)
# * [비주얼알고](http://visualgo.net/sorting.html)
# * [의사 코드를 사용한 정렬 알고리즘 애니메이션](http://www.sorting-algorithms.com/merge-sort)

# %%
def merge_sort(arr):

    if len(arr) > 1:
        mid = len(arr) // 2
        lefthalf = arr[:mid]
        righthalf = arr[mid:]

        merge_sort(lefthalf)
        merge_sort(righthalf)

        i = 0
        j = 0
        k = 0
        while i < len(lefthalf) and j < len(righthalf):
            if lefthalf[i] < righthalf[j]:
                arr[k] = lefthalf[i]
                i = i + 1
            else:
                arr[k] = righthalf[j]
                j = j + 1
            k = k + 1

        while i < len(lefthalf):
            arr[k] = lefthalf[i]
            i = i + 1
            k = k + 1

        while j < len(righthalf):
            arr[k] = righthalf[j]
            j = j + 1
            k = k + 1

# %%
arr = [11, 2, 5, 4, 7, 6, 8, 1, 23]
merge_sort(arr)
arr
# Out:
# [1, 2, 4, 5, 6, 7, 8, 11, 23]

# %% [markdown]
# # 잘했어요!
