# %% [markdown]
# # 선택 정렬 구현
#
# 선택 정렬은 목록을 통과할 때마다 한 번만 교환함으로써 버블 정렬을 개선합니다. 이를 위해 선택 정렬은 패스를 만들 때 가장 큰 값을 찾고 패스를 완료한 후 이를 적절한 위치에 배치합니다. 버블 정렬과 마찬가지로 첫 번째 통과 후에 가장 큰 항목이 올바른 위치에 있습니다. 두 번째 패스 후에는 다음으로 큰 패스가 배치됩니다. 이 프로세스는 계속되며 n 항목을 정렬하려면 n-1번의 단계가 필요합니다. 왜냐하면 최종 항목은 (n-1)번째 단계 이후에 있어야 하기 때문입니다.

# %% [markdown]
# # 검토를 위한 리소스
#
# 선택 정렬에 대한 검토는 아래 리소스를 확인하세요!
#
# * [위키피디아](https://en.wikipedia.org/wiki/Selection_sort)
# * [비주얼알고](http://visualgo.net/sorting.html)
# * [애니메이션](http://cs.armstrong.edu/liang/animation/web/SelectionSort.html)
# * [의사 코드를 사용한 정렬 알고리즘 애니메이션](http://www.sorting-algorithms.com/selection-sort)

# %%
def selection_sort(arr):

    # For every slot in array
    for fillslot in range(len(arr) - 1, 0, -1):
        positionOfMax = 0

        # For every set of 0 to fillslot+1
        for location in range(1, fillslot + 1):
            # Set maximum's location
            if arr[location] > arr[positionOfMax]:
                positionOfMax = location

        temp = arr[fillslot]
        arr[fillslot] = arr[positionOfMax]
        arr[positionOfMax] = temp

# %%
arr = [3, 5, 2, 7, 6, 8, 12, 40, 21]
selection_sort(arr)
arr
# Out:
# [2, 3, 5, 6, 7, 8, 12, 21, 40]

# %% [markdown]
# # 잘했어요!
