# %% [markdown]
# # 깊이 우선 검색 알고리즘 구현

# %% [markdown]
# 이 문제를 해결하려면 DFS 알고리즘을 구현하세요! 그래프가 단순화된 형태라고 가정할 수 있습니다.

# %%
graph = {
    "A": set(["B", "C"]),
    "B": set(["A", "D", "E"]),
    "C": set(["A", "F"]),
    "D": set(["B"]),
    "E": set(["B", "F"]),
    "F": set(["C", "E"]),
}

# %% [markdown]
# # 행운을 빌어요!
