# %% [markdown]
# # 스택, 큐, 데크 개요

# %% [markdown]
# 이번 강좌에서는 Stack, Queue, Deque에 대해 배워보겠습니다. 이것은 선형 구조입니다. 이는 배열과 유사하지만 각 구조는 항목을 추가하고 제거하는 방법에 따라 다릅니다.
#
# 이 섹션에서 기대할 수 있는 내용은 다음과 같습니다.
#
#     1.) 선형 구조에 대한 간략한 개요
#     2.) 스택 개요
#     3.) Stack 클래스의 구현
#     4.) 대기열 개요
#     5.) Queue 클래스 구현
#     6.) Deques 개요
#     7.) Deque 클래스 구현
#
#     그리고 마지막으로 Stacks, Queues, Deques 기반의 다양한 면접 질문!
#
# **과정의 이 섹션에 대한 전체 분석은 강의 비디오를 참조하세요!**
