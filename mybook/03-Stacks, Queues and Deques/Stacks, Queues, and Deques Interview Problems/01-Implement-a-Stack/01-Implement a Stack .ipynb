# %% [markdown]
# # 스택 구현
#
# 매우 일반적인 인터뷰 질문은 스택을 구현하는 것부터 시작하는 것입니다! 자신만의 스택을 구현하기 위해 최선을 다하십시오!
#
# 다음과 같은 메소드가 있어야 합니다.
#
# * 비어 있는지 확인
# * 새 항목 푸시
# * 아이템 팝
# * 상단 항목 엿보기
# * 사이즈 반환

# %%
class Stack(object):
    # Fill out the Stack Methods here
    pass
