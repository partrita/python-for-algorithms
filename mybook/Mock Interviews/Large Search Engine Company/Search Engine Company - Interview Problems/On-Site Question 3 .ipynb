# %% [markdown]
# # 현장질문 3
#
# ## 질문
#
# **문자열이 주어지면 재귀를 사용하여 이를 되돌리는 함수를 작성하세요.
#
# ## 요구사항
#
# 이 질문에 답하려면 반드시 펜과 종이 또는 화이트보드를 사용해야 합니다. 코딩은 허용되지 않습니다!

# %% [markdown]
# ____

# %% [markdown]
# # 행운을 빌어요!
